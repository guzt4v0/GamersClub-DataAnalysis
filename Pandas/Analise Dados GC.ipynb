# %%
import pandas as pd

# %%
# pd.options.display.max_rows = 4000

# %%
df = pd.read_csv("data/tb_lobby_stats_player.csv", sep=",")

# %%
df.head(10)
# Out:
#    idLobbyGame  idPlayer  idRoom  qtKill  qtAssist  qtDeath  qtHs  \
# 0            1         1       1       5         1       16     2
# 1            2         1       2      24         3       18     6
# 2            3         2       3       6         4       23     2
# 3            3       391   27508      10         5       20     4
# 4            4         2       4       8         4       26     6
# 5            5         2       5      10         1       11     5
# 6            5      1068   69976       9         2       19     4
# 7            6         2       6      16         1       23     9
# 8            7         2       7      11         2       19     2
# 9            8         2       8       8         6       13     2
#
#    qtBombeDefuse  qtBombePlant  qtTk  ...  qtFlashAssist  qtHitHeadshot  \
# 0              0             0   0.0  ...            0.0            3.0
# 1              0             4   0.0  ...            0.0            7.0
# ...

# %% [markdown]
# ## Numero de Players

# %%
players = df["idPlayer"]
type(players)
players.drop_duplicates(inplace=True)
players.count()
# Out:
# 2469

# %% [markdown]
# ## Mapas mais jogados

# %%
df["descMapName"].value_counts(normalize=True)
# Out:
# de_mirage      0.315506
# de_inferno     0.228469
# de_dust2       0.129426
# de_vertigo     0.108193
# de_overpass    0.076502
# de_nuke        0.076312
# de_train       0.042606
# de_ancient     0.022986
# Name: descMapName, dtype: float64

# %% [markdown]
# ## Mapas mais jogados por Nível

# %%
df["vlLevel"]
# Out:
# 0         10
# 1          9
# 2          2
# 3         15
# 4          2
#           ..
# 184147     9
# 184148     9
# 184149     9
# 184150     9
# 184151     9
# Name: vlLevel, Length: 184152, dtype: int64

# %%
df[["vlLevel", "descMapName"]]
# Out:
#         vlLevel descMapName
# 0            10   de_mirage
# 1             9     de_nuke
# 2             2   de_mirage
# 3            15   de_mirage
# 4             2     de_nuke
# ...         ...         ...
# 184147        9  de_vertigo
# 184148        9     de_nuke
# 184149        9  de_vertigo
# 184150        9    de_dust2
# 184151        9  de_inferno
#
# [184152 rows x 2 columns]

# %%
df.groupby(["vlLevel", "descMapName"]).agg({"idLobbyGame": "count"})
# Out:
#                      idLobbyGame
# vlLevel descMapName
# 0       de_ancient             8
#         de_dust2             150
#         de_inferno           232
#         de_mirage            448
#         de_nuke               44
# ...                          ...
# 21      de_mirage            543
#         de_nuke               97
#         de_overpass           49
#         de_train              96
#         de_vertigo           265
#
# [176 rows x 1 columns]

# %% [markdown]
# ## Quantidade de HS por NVL

# %%
df.groupby(["vlLevel"]).agg({"qtHs": ["sum", "mean"]})
# Out:
#            qtHs
#             sum       mean
# vlLevel
# 0          6877   6.506149
# 1          1019   4.354701
# 2          2637   3.995455
# 3         10248   4.457590
# 4         14208   4.947075
# 5         20563   5.347984
# 6         24508   5.740923
# 7         27899   5.989480
# 8         38278   6.177857
# 9         60488   6.598451
# 10        92324   6.748830
# 11        81262   6.998708
# 12        82763   7.297038
# 13        93017   7.485675
# 14        92059   7.620147
# 15       111316   7.838051
# 16        99539   7.997027
# 17        98474   8.138347
# 18       114460   8.352915
# 19       138246   8.834739
# 20       182681   9.982023
# 21        14078  10.397341

# %% [markdown]
# ## Partes do Corpo Mais Acertadas

# %%
playersHit = df[["idPlayer", "qtHitHeadshot", "qtHitChest", "qtHitStomach", "qtHitLeftAtm", "qtHitRightArm", "qtHitLeftLeg", "qtHitRightLeg"]]
playersHit
# Out:
#         idPlayer  qtHitHeadshot  qtHitChest  qtHitStomach  qtHitLeftAtm  \
# 0              1            3.0        13.0           4.0           2.0
# 1              1            7.0        26.0          14.0           2.0
# 2              2            3.0        15.0           8.0           1.0
# 3            391            6.0        27.0          10.0           1.0
# 4              2            8.0        19.0          12.0           2.0
# ...          ...            ...         ...           ...           ...
# 184147      2716            7.0        42.0          26.0           1.0
# 184148      2716            5.0        21.0          21.0           3.0
# 184149      2716            3.0        25.0          12.0           1.0
# 184150      2716            8.0        22.0          16.0           2.0
# 184151      2716            7.0        17.0           9.0           5.0
#
#         qtHitRightArm  qtHitLeftLeg  qtHitRightLeg
# 0                 2.0           1.0            0.0
# ...

# %%
playersHit = playersHit.set_index("idPlayer")
playersHit
# Out:
#           qtHitHeadshot  qtHitChest  qtHitStomach  qtHitLeftAtm  \
# idPlayer
# 1                   3.0        13.0           4.0           2.0
# 1                   7.0        26.0          14.0           2.0
# 2                   3.0        15.0           8.0           1.0
# 391                 6.0        27.0          10.0           1.0
# 2                   8.0        19.0          12.0           2.0
# ...                 ...         ...           ...           ...
# 2716                7.0        42.0          26.0           1.0
# 2716                5.0        21.0          21.0           3.0
# 2716                3.0        25.0          12.0           1.0
# 2716                8.0        22.0          16.0           2.0
# 2716                7.0        17.0           9.0           5.0
#
#           qtHitRightArm  qtHitLeftLeg  qtHitRightLeg
# idPlayer
# 1                   2.0           1.0            0.0
# 1                   1.0           1.0            3.0
# ...
