# %%
import pandas as pd

# %%
df = pd.read_csv("data/tb_lobby_stats_player.csv", sep=",")

# %%
df.head(10)
# Out:
#    idLobbyGame  idPlayer  idRoom  qtKill  qtAssist  qtDeath  qtHs  \
# 0            1         1       1       5         1       16     2
# 1            2         1       2      24         3       18     6
# 2            3         2       3       6         4       23     2
# 3            3       391   27508      10         5       20     4
# 4            4         2       4       8         4       26     6
# 5            5         2       5      10         1       11     5
# 6            5      1068   69976       9         2       19     4
# 7            6         2       6      16         1       23     9
# 8            7         2       7      11         2       19     2
# 9            8         2       8       8         6       13     2
#
#    qtBombeDefuse  qtBombePlant  qtTk  ...  qtFlashAssist  qtHitHeadshot  \
# 0              0             0   0.0  ...            0.0            3.0
# 1              0             4   0.0  ...            0.0            7.0
# 2              0             1   0.0  ...            0.0            3.0
# 3              1             0   0.0  ...            0.0            6.0
# 4              0             2   0.0  ...            2.0            8.0
# 5              0             3   0.0  ...            1.0            5.0
# 6              1             0   0.0  ...            1.0            6.0
# 7              0             1   0.0  ...            1.0            9.0
# 8              0             1   0.0  ...            1.0            5.0
# 9              0             0   0.0  ...            0.0            3.0
#
#    qtHitChest  qtHitStomach  qtHitLeftAtm  qtHitRightArm  qtHitLeftLeg  \
# 0        13.0           4.0           2.0            2.0           1.0
# 1        26.0          14.0           2.0            1.0           1.0
# 2        15.0           8.0           1.0            2.0           0.0
# 3        27.0          10.0           1.0            7.0           6.0
# 4        19.0          12.0           2.0            3.0           2.0
# 5         6.0           8.0           0.0            0.0           3.0
# 6        21.0          14.0           3.0            4.0           2.0
# 7        21.0          19.0           3.0            4.0           2.0
# 8        17.0          12.0           0.0            4.0           0.0
# 9         9.0          17.0           2.0            5.0           7.0
#
#    qtHitRightLeg  flWinner          dtCreatedAt
# 0            0.0         0  2022-01-21 19:45:44
# 1            3.0         1  2022-02-04 02:09:47
# 2            2.0         0  2021-09-18 18:07:43
# 3            6.0         1  2021-09-18 18:07:43
# 4            5.0         0  2021-09-27 00:17:45
# 5            0.0         1  2021-09-29 22:05:47
# 6            2.0         0  2021-09-29 22:05:47
# 7            3.0         0  2021-10-07 22:48:43
# 8            2.0         0  2021-10-08 23:29:57
# 9            8.0         0  2021-10-12 16:48:09
#
# [10 rows x 38 columns]

# %% [markdown]
# ## Numero de Players

# %%
players = df["idPlayer"]
type(players)
players.drop_duplicates(inplace=True)
players.count()
# Out:
# 2469

# %% [markdown]
# ## Mapas mais jogados

# %%
df["descMapName"].value_counts(normalize=True)
# Out:
# de_mirage      0.315506
# de_inferno     0.228469
# de_dust2       0.129426
# de_vertigo     0.108193
# de_overpass    0.076502
# de_nuke        0.076312
# de_train       0.042606
# de_ancient     0.022986
# Name: descMapName, dtype: float64

# %% [markdown]
# ## Mapas mais jogados por Nível

# %%
df[["vlLevel", "descMapName"]]
# Out:
#         vlLevel descMapName
# 0            10   de_mirage
# 1             9     de_nuke
# 2             2   de_mirage
# 3            15   de_mirage
# 4             2     de_nuke
# ...         ...         ...
# 184147        9  de_vertigo
# 184148        9     de_nuke
# 184149        9  de_vertigo
# 184150        9    de_dust2
# 184151        9  de_inferno
#
# [184152 rows x 2 columns]

# %%
df.groupby(["vlLevel", "descMapName"]).agg({"idLobbyGame": "count"})
# Out:
#                      idLobbyGame
# vlLevel descMapName
# 0       de_ancient             8
#         de_dust2             150
#         de_inferno           232
#         de_mirage            448
#         de_nuke               44
# ...                          ...
# 21      de_mirage            543
#         de_nuke               97
#         de_overpass           49
#         de_train              96
#         de_vertigo           265
#
# [176 rows x 1 columns]

# %% [markdown]
# ## Soma e Média de HS por NVL

# %%
df.groupby(["vlLevel"]).agg({"qtHs": ["sum", "mean"]})
# Out:
#            qtHs
#             sum       mean
# vlLevel
# 0          6877   6.506149
# 1          1019   4.354701
# 2          2637   3.995455
# 3         10248   4.457590
# 4         14208   4.947075
# 5         20563   5.347984
# 6         24508   5.740923
# 7         27899   5.989480
# 8         38278   6.177857
# 9         60488   6.598451
# 10        92324   6.748830
# 11        81262   6.998708
# 12        82763   7.297038
# 13        93017   7.485675
# 14        92059   7.620147
# 15       111316   7.838051
# 16        99539   7.997027
# 17        98474   8.138347
# 18       114460   8.352915
# 19       138246   8.834739
# 20       182681   9.982023
# 21        14078  10.397341

# %% [markdown]
# ## Partes do Corpo Mais Acertadas por Level

# %%
lvHit = df[["vlLevel", "qtHitHeadshot", "qtHitChest", "qtHitStomach", "qtHitLeftAtm", "qtHitRightArm", "qtHitLeftLeg", "qtHitRightLeg"]]
lvHit
# Out:
#         vlLevel  qtHitHeadshot  qtHitChest  qtHitStomach  qtHitLeftAtm  \
# 0            10            3.0        13.0           4.0           2.0
# 1             9            7.0        26.0          14.0           2.0
# 2             2            3.0        15.0           8.0           1.0
# 3            15            6.0        27.0          10.0           1.0
# 4             2            8.0        19.0          12.0           2.0
# ...         ...            ...         ...           ...           ...
# 184147        9            7.0        42.0          26.0           1.0
# 184148        9            5.0        21.0          21.0           3.0
# 184149        9            3.0        25.0          12.0           1.0
# 184150        9            8.0        22.0          16.0           2.0
# 184151        9            7.0        17.0           9.0           5.0
#
#         qtHitRightArm  qtHitLeftLeg  qtHitRightLeg
# 0                 2.0           1.0            0.0
# 1                 1.0           1.0            3.0
# 2                 2.0           0.0            2.0
# 3                 7.0           6.0            6.0
# 4                 3.0           2.0            5.0
# ...               ...           ...            ...
# 184147            4.0           6.0            2.0
# 184148            7.0           2.0            4.0
# 184149            5.0           6.0            7.0
# 184150            8.0           3.0            6.0
# 184151            4.0           6.0            1.0
#
# [184152 rows x 8 columns]

# %%
lvHit = lvHit.set_index("vlLevel")
lvHit
# Out:
#          qtHitHeadshot  qtHitChest  qtHitStomach  qtHitLeftAtm  qtHitRightArm  \
# vlLevel
# 10                 3.0        13.0           4.0           2.0            2.0
# 9                  7.0        26.0          14.0           2.0            1.0
# 2                  3.0        15.0           8.0           1.0            2.0
# 15                 6.0        27.0          10.0           1.0            7.0
# 2                  8.0        19.0          12.0           2.0            3.0
# ...                ...         ...           ...           ...            ...
# 9                  7.0        42.0          26.0           1.0            4.0
# 9                  5.0        21.0          21.0           3.0            7.0
# 9                  3.0        25.0          12.0           1.0            5.0
# 9                  8.0        22.0          16.0           2.0            8.0
# 9                  7.0        17.0           9.0           5.0            4.0
#
#          qtHitLeftLeg  qtHitRightLeg
# vlLevel
# 10                1.0            0.0
# 9                 1.0            3.0
# 2                 0.0            2.0
# 15                6.0            6.0
# 2                 2.0            5.0
# ...               ...            ...
# 9                 6.0            2.0
# 9                 2.0            4.0
# 9                 6.0            7.0
# 9                 3.0            6.0
# 9                 6.0            1.0
#
# [184152 rows x 7 columns]

# %%
groupLvHit = lvHit.groupby("vlLevel").sum().plot()
groupLvHit
# Out:
# <AxesSubplot:xlabel='vlLevel'>

# %% [markdown]
# ## K/D dos Nvl

# %%
kdTabel = df[['vlLevel', 'qtKill', 'qtDeath']]
kdTabel
# Out:
#         vlLevel  qtKill  qtDeath
# 0            10       5       16
# 1             9      24       18
# 2             2       6       23
# 3            15      10       20
# 4             2       8       26
# ...         ...     ...      ...
# 184147        9      21       13
# 184148        9      15       22
# 184149        9       9       23
# 184150        9      15       20
# 184151        9      12       11
#
# [184152 rows x 3 columns]

# %%
kdTabel = kdTabel.set_index("vlLevel")
kdTabel
# Out:
#          qtKill  qtDeath
# vlLevel
# 10            5       16
# 9            24       18
# 2             6       23
# 15           10       20
# 2             8       26
# ...         ...      ...
# 9            21       13
# 9            15       22
# 9             9       23
# 9            15       20
# 9            12       11
#
# [184152 rows x 2 columns]

# %%
kdGroup = kdTabel.groupby(['vlLevel']).mean().round(2)
kdGroup
# Out:
#          qtKill  qtDeath
# vlLevel
# 0         16.51    17.10
# 1         11.79    18.15
# 2         11.85    18.43
# 3         13.22    18.35
# 4         14.37    18.64
# 5         15.42    18.71
# 6         16.11    18.73
# 7         16.27    18.38
# 8         17.10    18.49
# 9         17.77    18.48
# 10        17.97    18.50
# 11        18.43    18.72
# 12        18.87    18.89
# 13        18.93    18.86
# 14        19.12    19.03
# 15        19.51    18.89
# 16        19.81    19.08
# 17        19.99    19.03
# 18        20.45    19.01
# 19        20.80    19.01
# 20        22.00    18.68
# 21        24.83    17.81

# %%
meanKD = kdGroup.assign(KD = lambda x: (x['qtKill'] / x['qtDeath'])).round(2)
meanKD
# Out:
#          qtKill  qtDeath    KD
# vlLevel
# 0         16.51    17.10  0.97
# 1         11.79    18.15  0.65
# 2         11.85    18.43  0.64
# 3         13.22    18.35  0.72
# 4         14.37    18.64  0.77
# 5         15.42    18.71  0.82
# 6         16.11    18.73  0.86
# 7         16.27    18.38  0.89
# 8         17.10    18.49  0.92
# 9         17.77    18.48  0.96
# 10        17.97    18.50  0.97
# 11        18.43    18.72  0.98
# 12        18.87    18.89  1.00
# 13        18.93    18.86  1.00
# 14        19.12    19.03  1.00
# 15        19.51    18.89  1.03
# 16        19.81    19.08  1.04
# 17        19.99    19.03  1.05
# 18        20.45    19.01  1.08
# 19        20.80    19.01  1.09
# 20        22.00    18.68  1.18
# 21        24.83    17.81  1.39
