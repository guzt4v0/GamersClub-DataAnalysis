# %%
import pandas as pd

# %%
df = pd.read_csv("data/tb_lobby_stats_player.csv")

# %%
df.head()
# Out:
#    idLobbyGame  idPlayer  idRoom  qtKill  qtAssist  qtDeath  qtHs  \
# 0            1         1       1       5         1       16     2
# 1            2         1       2      24         3       18     6
# 2            3         2       3       6         4       23     2
# 3            3       391   27508      10         5       20     4
# 4            4         2       4       8         4       26     6
#
#    qtBombeDefuse  qtBombePlant  qtTk  ...  qtFlashAssist  qtHitHeadshot  \
# 0              0             0   0.0  ...            0.0            3.0
# 1              0             4   0.0  ...            0.0            7.0
# 2              0             1   0.0  ...            0.0            3.0
# 3              1             0   0.0  ...            0.0            6.0
# 4              0             2   0.0  ...            2.0            8.0
#
#    qtHitChest  qtHitStomach  qtHitLeftAtm  qtHitRightArm  qtHitLeftLeg  \
# ...

# %%
df["idPlayer"].value_counts(ascending=True)
# Out:
# 2622      1
# 8         1
# 2521      1
# 2646      1
# 1190      1
#        ...
# 1335    625
# 20      666
# 2289    677
# 1663    746
# 1922    873
# Name: idPlayer, Length: 2469, dtype: int64

# %%
df["descMapName"].value_counts(normalize=True)
# Out:
# de_mirage      0.315506
# de_inferno     0.228469
# de_dust2       0.129426
# de_vertigo     0.108193
# de_overpass    0.076502
# de_nuke        0.076312
# de_train       0.042606
# de_ancient     0.022986
# Name: descMapName, dtype: float64
